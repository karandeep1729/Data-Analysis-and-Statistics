# %% [markdown]
# <a href="https://colab.research.google.com/github/karandeep1729/Data-Analysis-and-Statistics/blob/main/USHoneyCaseStudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Dataset Link:** https://drive.google.com/file/d/1bSh2GGDUsd47fFV0j1VaLVaex40uxycl/view?usp=drive_link

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/US_honey_dataset.csv')
df
# Out:
#       Unnamed: 0         state  colonies_number  yield_per_colony  production  \
# 0              0       Alabama            16000                58      928000
# 1              1       Arizona            52000                79     4108000
# 2              2      Arkansas            50000                60     3000000
# 3              3    California           420000                93    39060000
# 4              4      Colorado            45000                60     2700000
# ...          ...           ...              ...               ...         ...
# 1110        1110      Virginia             6000                40       79000
# 1111        1111    Washington            96000                32     1206000
# 1112        1112  WestVirginia             6000                43      136000
# 1113        1113     Wisconsin            42000                47      750000
# 1114        1114       Wyoming            38000                58      242000
#
# ...

# %%
df.head(50)
# Out:
#     Unnamed: 0          state  colonies_number  yield_per_colony  production  \
# 0            0        Alabama            16000                58      928000
# 1            1        Arizona            52000                79     4108000
# 2            2       Arkansas            50000                60     3000000
# 3            3     California           420000                93    39060000
# 4            4       Colorado            45000                60     2700000
# 5            5        Florida           230000                86    19780000
# 6            6        Georgia            70000                62     4340000
# 7            7         Hawaii             8000               129     1032000
# 8            8          Idaho           125000                48     6000000
# 9            9       Illinois            11000                74      814000
# 10          10        Indiana            12000                63      756000
# ...

# %% [markdown]
# **Check the info, null values, number of rows and columns, duplicate values. You have to delete the unnecessary column.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1115 non-null   int64
#  1   state                1115 non-null   object
#  2   colonies_number      1115 non-null   int64
#  3   yield_per_colony     1115 non-null   int64
#  4   production           1115 non-null   int64
#  5   stocks               1115 non-null   int64
#  6   average_price        1115 non-null   float64
#  7   value_of_production  1115 non-null   int64
#  8   year                 1115 non-null   int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 78.5+ KB

# %%
df.shape # To get the number of rows and number of columns.
# Out:
# (1115, 9)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# df.drop('Unnamed: 0',axis=1,inplace=True)
df = df.drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#              state  colonies_number  yield_per_colony  production   stocks  \
# 0          Alabama            16000                58      928000    28000
# 1          Arizona            52000                79     4108000   986000
# 2         Arkansas            50000                60     3000000   900000
# 3       California           420000                93    39060000  4687000
# 4         Colorado            45000                60     2700000  1404000
# ...            ...              ...               ...         ...      ...
# 1110      Virginia             6000                40       79000    79000
# 1111    Washington            96000                32     1206000  1206000
# 1112  WestVirginia             6000                43      136000   136000
# 1113     Wisconsin            42000                47      750000   750000
# 1114       Wyoming            38000                58      242000   242000
#
#       average_price  value_of_production  year
# ...

# %% [markdown]
# **Find the top and bottom 5 states on the basis of production**

# %%
# Use the groupby function on production with respect to State.
states_production = df.groupby('state')['production'].sum().reset_index()
states_production
# Out:
#             state  production
# 0         Alabama    14467000
# 1         Arizona    38844000
# 2        Arkansas    51846000
# 3      California   423876000
# 4        Colorado    32660000
# 5         Florida   280934000
# 6         Georgia    57426000
# 7          Hawaii    15420000
# 8           Idaho    87188000
# 9        Illinois     9864000
# 10        Indiana     9686000
# 11           Iowa    48607000
# 12         Kansas    14138000
# 13       Kentucky     3224000
# 14      Louisiana    60568000
# 15          Maine     4762000
# 16       Maryland     1975000
# 17       Michigan   101063000
# 18      Minnesota   176581000
# 19    Mississippi    21235000
# 20       Missouri    17904000
# 21        Montana   197173000
# 22       Nebraska    63655000
# 23         Nevada     7399000
# 24      NewJersey     6913000
# 25      NewMexico    10082000
# 26        NewYork    78444000
# 27  NorthCarolina     8909000
# 28    NorthDakota   513742000
# 29           Ohio    22485000
# ...

# %%
states_production.index
# Out:
# RangeIndex(start=0, stop=44, step=1)

# %%
# Selecting the top 5 best producing states.
top_5_states = states_production.sort_values(by='production',ascending=False).head()
top_5_states
# Out:
#           state  production
# 28  NorthDakota   513742000
# 3    California   423876000
# 34  SouthDakota   355726000
# 5       Florida   280934000
# 21      Montana   197173000

# %%
# Select the top 5 worst producing states.
bottom_5_states = states_production.sort_values(by='production',ascending=True).head()
bottom_5_states
# Out:
#             state  production
# 16       Maryland     1975000
# 30       Oklahoma     2055000
# 33  SouthCarolina     2823000
# 13       Kentucky     3224000
# 15          Maine     4762000

# %% [markdown]
# **Create two bar plots for these top_5_states and bottom_5_states**

# %%
# fig = plt.subplots(1,2,figsize=(10,10))

# plt.subplot(1,2,1)
# plt.bar(top_5_states['state'],top_5_states['production'])
# plt.xlabel('State')
# plt.ylabel('Production')
# plt.title('Top Performing States')

# plt.subplot(1,2,2)
# sns.barplot(x='state',y='production',data=bottom_5_states)
# plt.xlabel('State')
# plt.ylabel('Production')
# plt.title('Worst Performing States')
# plt.show()                                                          Query

# %%
# bottom 5 states
sns.barplot(x='state',y='production',data=bottom_5_states)
plt.xlabel('State')
plt.ylabel('Production')
plt.title('Worst Performing States')
plt.show()

# %%
plt.bar(top_5_states['state'], top_5_states['production'])
plt.xlabel('State')
plt.ylabel('Total Production')
plt.title('Top 5 States by Honey Production')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Find out how much the change in mean average price of Honey from 1995 to 2021**

# %%
mean_avg = df.groupby('year')['average_price'].mean().reset_index()
mean_avg
# Out:
#     year  average_price
# 0   1995      74.840909
# 1   1996      99.568182
# 2   1997      91.325581
# 3   1998      83.720930
# 4   1999      80.325581
# 5   2000      79.023256
# 6   2001      88.465116
# 7   2002     133.204545
# 8   2003     151.068182
# 9   2004     132.350000
# 10  2005     116.341463
# 11  2006     134.341463
# 12  2007     140.170732
# 13  2008     160.878049
# 14  2009     176.195122
# 15  2010     192.900000
# 16  2011     216.725000
# 17  2012     236.700000
# 18  2013     260.717949
# 19  2014     282.025000
# 20  2015     292.625000
# 21  2016     291.925000
# 22  2017     302.775000
# 23  2018       3.083500
# 24  2019       2.925500
# 25  2020       3.050000
# 26  2021       3.334250

# %%
mean_avg.iloc[0]
# Out:
# year             1995.000000
# average_price      74.840909
# Name: 0, dtype: float64

# %%
change_mean = mean_avg.iloc[0] - mean_avg.iloc[-1]
change_mean
# Out:
# year            -26.000000
# average_price    71.506659
# dtype: float64

# %% [markdown]
# **Which was the year when production of Honey in whole US was highest**

# %%
total_prod = df.groupby('year')['production'].sum().reset_index()
total_prod
# Out:
#     year  production
# 0   1995   210272000
# 1   1996   197995000
# 2   1997   191176000
# 3   1998   219321000
# 4   1999   204585000
# 5   2000   220320000
# 6   2001   185403000
# 7   2002   170732000
# 8   2003   180741000
# 9   2004   182379000
# 10  2005   173857000
# 11  2006   154120000
# 12  2007   147609000
# 13  2008   160096000
# 14  2009   143340000
# 15  2010    44797000
# 16  2011    36550000
# 17  2012    31662000
# 18  2013    37974000
# 19  2014    40990000
# 20  2015    41832000
# 21  2016    40837000
# 22  2017    30478000
# 23  2018    28989000
# 24  2019    40510000
# 25  2020    39412000
# 26  2021    23187000

# %%
max_production_year = total_prod.sort_values(by='production',ascending=False).head(2)
max_production_year
# Out:
#    year  production
# 5  2000   220320000
# 3  1998   219321000

# %%
highest_production = df.groupby('year')['production'].sum().reset_index()
highest_production.max()
# Out:
# year               2021
# production    220320000
# dtype: int64

# %% [markdown]
# **Find out which state was most contributing to make the year 2000 as the max producer**

# %%
# production but with respect to year and state.
all_states = df.groupby(['state','year'])['production'].sum().reset_index()
all_states
# Out:
#         state  year  production
# 0     Alabama  1995      928000
# 1     Alabama  1996     1024000
# 2     Alabama  1997      924000
# 3     Alabama  1998     1136000
# 4     Alabama  1999     1156000
# ...       ...   ...         ...
# 1110  Wyoming  2017      186000
# 1111  Wyoming  2018      175000
# 1112  Wyoming  2019      306000
# 1113  Wyoming  2020      608000
# 1114  Wyoming  2021      242000
#
# [1115 rows x 3 columns]

# %%
# Now we will select all the rows where the year is 2000.
state_2000_contribution = all_states.loc[(all_states['year']==2000)].reset_index()

# %%
# state_2000_contribution[state_2000_contribution['year']==2000]
# Out:
#     index          state  year  production
# 0       5        Alabama  2000     1248000
# 1      32        Arizona  2000     2360000
# 2      59       Arkansas  2000     5115000
# 3      86     California  2000    30800000
# 4     113       Colorado  2000     1740000
# 5     140        Florida  2000    24360000
# 6     167        Georgia  2000     3135000
# 7     194         Hawaii  2000      784000
# 8     221          Idaho  2000     4700000
# 9     248       Illinois  2000      488000
# 10    275        Indiana  2000      520000
# 11    302           Iowa  2000     2010000
# 12    329         Kansas  2000     1020000
# 13    356       Kentucky  2000      144000
# 14    382      Louisiana  2000     4042000
# 15    409          Maine  2000      231000
# 16    436       Maryland  2000      276000
# 17    445       Michigan  2000     5400000
# 18    472      Minnesota  2000    13500000
# 19    499    Mississippi  2000     1224000
# 20    526       Missouri  2000     1725000
# ...

# %%
state_2000_contribution
# Out:
#     index          state  year  production
# 0       5        Alabama  2000     1248000
# 1      32        Arizona  2000     2360000
# 2      59       Arkansas  2000     5115000
# 3      86     California  2000    30800000
# 4     113       Colorado  2000     1740000
# 5     140        Florida  2000    24360000
# 6     167        Georgia  2000     3135000
# 7     194         Hawaii  2000      784000
# 8     221          Idaho  2000     4700000
# 9     248       Illinois  2000      488000
# 10    275        Indiana  2000      520000
# 11    302           Iowa  2000     2010000
# 12    329         Kansas  2000     1020000
# 13    356       Kentucky  2000      144000
# 14    382      Louisiana  2000     4042000
# 15    409          Maine  2000      231000
# 16    436       Maryland  2000      276000
# 17    445       Michigan  2000     5400000
# 18    472      Minnesota  2000    13500000
# 19    499    Mississippi  2000     1224000
# 20    526       Missouri  2000     1725000
# ...

# %%
max_contri_state_2000 = state_2000_contribution.sort_values(by='production',ascending=False).head(1)
max_contri_state_2000
# Out:
#     index        state  year  production
# 28    721  NorthDakota  2000    33350000

# %% [markdown]
# **Which State has the highest number of colonies in the year 2000.**

# %%
# sns.heatmap(df.corr(numeric_only=True),cmap='coolwarm',annot=True)   Query
# Out:
# <Axes: >
